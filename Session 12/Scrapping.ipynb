# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://wuzzuf.net/search/jobs/?q=call+center&a=hpb"

# %%
site = requests.get(url)
site
# Out:
# <Response [403]>

# %%
website = requests.get("https://wuzzuf.net/search/jobs/?q=call+center&a=hpb").text
website
# Out:
# '<!DOCTYPE html>\n<html lang="en" translate="no">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, shrink-to-fit=no">\n    <meta http-equiv="expires" content="Thu Dec 08 2022 18:30:44 GMT+0200" />\n\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate">\n    <meta name="googlebot" content="notranslate">\n    <title data-react-helmet="true">Job Search | WUZZUF</title>\n\n<meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" name="description" content="Searching for jobs in Egypt? Wuzzuf helps you in your online job search to find Jobs in Egypt and Middle East. Choose the right job using our online recruitment services."/><meta data-react-helmet="true" name="keywords" content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employme
# ...

# %%
website = BeautifulSoup(website, "lxml")
website
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">Job Search | WUZZUF</title>
# ...

# %%
type(website)
# Out:
# bs4.BeautifulSoup

# %%
website.title
# Out:
# <title data-react-helmet="true">Job Search | WUZZUF</title>

# %%
job = website.find("div", class_ = "css-pkv5jc")
job
# Out:
# <div class="css-pkv5jc"><a href="https://wuzzuf.net/jobs/careers/OPPO-Egypt-For-Trade-and-Distribution-Egypt-7132" rel="noreferrer" target="_blank"><style data-emotion="css 17095x3">.css-17095x3{position:absolute;right:0;top:0;width:60px;height:60px;object-fit:contain;object-position:center center;}</style></a><style data-emotion="css laomuu">.css-laomuu{padding-right:60px;}</style><div class="css-laomuu"><style data-emotion="css m604qf">.css-m604qf{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#0055D9;margin:0;}</style><h2 class="css-m604qf"><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/Tb0xkTo6Yt5M-Call-Center-Agent-OPPO-Egypt-Cairo-Egypt" rel="noreferrer" target="_blank">Call Center Agent</a></h2><style data-emotion="css d7j1kk">.css-d7j1kk{margin-bottom:8px;overflow:hidden;text-overflow:ellipsis;}</style><div
# ...

# %%
jobtitle = website.find("a", class_ = "css-o171kl").text
jobtitle
# Out:
# 'Call Center Agent'

# %%
companyname = website.find("a", class_ = "css-17s97q8").text
companyname
# Out:
# 'OPPO Egypt  -'

# %%
location = website.find("span", class_ = "css-5wys0k").text
location
# Out:
# 'Nasr City, Cairo, Egypt '

# %%
jobtype = website.find("span", class_ = "css-1ve4b75 eoyjyou0").text
jobtype
# Out:
# 'Full Time'

# %%
date = website.find("div", class_ = "css-4c4ojb").text
date
# Out:
# '2 days ago'

# %%
jobs = website.find_all("div", class_ = "css-pkv5jc")

for job in jobs:
    jobtitle = job.find("a", class_ = "css-o171kl").text
    companyname = job.find("a", class_ = "css-17s97q8").text
    location = job.find("span", class_ = "css-5wys0k").text
    jobtype = job.find("span", class_ = "css-1ve4b75 eoyjyou0").text
    date = job.find("div", class_ = "css-4c4ojb").text
    
    print(jobtitle, companyname, location, jobtype, date)
# Out:
# Call Center Agent OPPO Egypt  - Nasr City, Cairo, Egypt  Full Time 2 days ago
# Call Center Advisor [Corporate Account] Etisalat Egypt - Maadi, Cairo, Egypt  Full Time 2 days ago
# Call Center Specialist [English] Etisalat Egypt - Maadi, Cairo, Egypt  Full Time 2 days ago
# English Call Center Agents(Services Company in UAE )… Majorel Egypt - Katameya, Cairo, Egypt  Full Time 24 hours ago
# Customer Service Assistant - Call Center Al Futtaim Group Aggregated - Cairo, Egypt  Full Time 4 days ago
# Call Center Agent Areeba Egypt - New Cairo, Cairo, Egypt  Full Time 2 days ago
# Call Center Agent Talaat Moustafa Group - Madinaty, Cairo, Egypt  Full Time 4 hours ago
# Call Center Advisor (English Queue), Etisalat UAE project (Corporate Account) Etisalat Egypt - Maadi, Cairo, Egypt  Full Time 19 hours ago
# Corporate Account- Call Center Representative Etisalat Egypt - Maadi, Cairo, Egypt  Full Time 2 days ago
# ...

# %%
import csv

# %%
csvfile = open('Jobs.csv', 'w', encoding='utf-8')
writer = csv.writer(csvfile)

# %%
writer.writerow(['job title', 'company name', 'location', 'job type', 'date'])
# Out:
# 47

# %%
jobs = website.find_all("div", class_ = "css-pkv5jc")

for job in jobs:
    jobtitle = job.find("a", class_ = "css-o171kl").text
    companyname = job.find("a", class_ = "css-17s97q8").text
    location = job.find("span", class_ = "css-5wys0k").text
    jobtype = job.find("span", class_ = "css-1ve4b75 eoyjyou0").text
    date = job.find("div", class_ = "css-4c4ojb").text
    writer.writerow([jobtitle, companyname, location, jobtype, date])
csvfile.close()

# %%
csvfile = open('Jobs.csv', 'w', encoding='utf-8')
writer = csv.writer(csvfile)
writer.writerow(['job title', 'company name', 'location', 'job type'])
for i in range (5):
    if i == 0: 
        url = "https://wuzzuf.net/search/jobs/?q=call+center&a=hpb"
    else:
        url = f"https://wuzzuf.net/search/jobs/?q=call+center&a=hpb&start={i}"
        website = requests.get(url).text
        website = BeautifulSoup(website , "lxml")
        jobs = website.find_all("div", class_ = "css-pkv5jc")

        for job in jobs:
            jobtitle = job.find("a", class_ = "css-o171kl").text
            companyname = job.find("a", class_ = "css-17s97q8").text
            location = job.find("span", class_ = "css-5wys0k").text
            jobtype = job.find("span", class_ = "css-1ve4b75 eoyjyou0").text
            writer.writerow([jobtitle, companyname, location, jobtype])
csvfile.close()
